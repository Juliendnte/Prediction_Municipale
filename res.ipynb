# %%
import os
import sys

# %%
sys.path.append(os.path.abspath('/'))

# %%
from src.preprocessing import load_and_clean_2001_res, load_and_clean_2008_res, load_and_clean_2014_res, load_and_clean_2020_res_tour1, load_and_clean_2020_res_tour2

# %%
df_2001 = load_and_clean_2001_res()
df_2008 = load_and_clean_2008_res()
df_2014 = load_and_clean_2014_res()
df_2020_tour1 = load_and_clean_2020_res_tour1()
df_2020_tour2 = load_and_clean_2020_res_tour2()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 df_2001 = load_and_clean_2001_res()
# ----> 2 df_2008 = load_and_clean_2008_res()
#       3 df_2014 = load_and_clean_2014_res()
#       4 df_2020_tour1 = load_and_clean_2020_res_tour1()
#
# File ~\OneDrive\Documents\info\B3\election\src\preprocessing.py:39, in load_and_clean_2008_res()
#      38 def load_and_clean_2008_res():
# ---> 39  df = pd.read_csv(RAW_DATA_FILES['2008_res'], sep=';' , encoding='iso-8859-1')
#      40  return df
#
# ...
