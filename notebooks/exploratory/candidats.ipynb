# %%
import sys
import os

# %%
sys.path.append(os.path.abspath('../..'))

# %%
from src.preprocessing import load_and_clean_candidats, load_and_clean_nuances

# %%
df = load_and_clean_candidats()
df.head()
# Out:
#   Code du département Libellé du département Code commune    Libellé commune  \
# 0                   1                    Ain            4  Ambérieu-en-Bugey
# 1                   1                    Ain            4  Ambérieu-en-Bugey
# 2                   1                    Ain            4  Ambérieu-en-Bugey
# 3                   1                    Ain            4  Ambérieu-en-Bugey
# 4                   1                    Ain            4  Ambérieu-en-Bugey
#
#    N° Panneau Liste Libellé abrégé liste Libellé Etendu Liste Nuance Liste  \
# 0                 1   UNIS POUR AMBERIEU   UNIS POUR AMBERIEU         LDVC
# 1                 1   UNIS POUR AMBERIEU   UNIS POUR AMBERIEU         LDVC
# 2                 1   UNIS POUR AMBERIEU   UNIS POUR AMBERIEU         LDVC
# 3                 1   UNIS POUR AMBERIEU   UNIS POUR AMBERIEU         LDVC
# 4                 1   UNIS POUR AMBERIEU   UNIS POUR AMBERIEU         LDVC
#
# ...

# %%
df.shape
# Out:
# (546142, 14)

# %%
df[['Nom candidat', 'Prénom candidat']].nunique()
# Out:
# Nom candidat       179900
# Prénom candidat     31566
# dtype: int64

# %%
df['nom prenom'] = df['Nom candidat'] + ' ' + df['Prénom candidat']

# %%
df['nom prenom'].nunique()
# Out:
# 509561

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546142 entries, 0 to 546141
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Code du département                546142 non-null  object
#  1   Libellé du département             546142 non-null  object
#  2   Code commune                       546142 non-null  object
#  3   Libellé commune                    546142 non-null  object
#  4   N° Panneau Liste                   546142 non-null  int64
#  5   Libellé abrégé liste               546101 non-null  object
#  6   Libellé Etendu Liste               545915 non-null  object
#  7   Nuance Liste                       337473 non-null  object
#  8   N° candidat                        546123 non-null  object
#  9   Sexe candidat                      546142 non-null  object
#  10  Nom candidat                       546142 non-null  object
# ...

# %%
df['Nuance Liste'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 546137    False
# 546138    False
# 546139    False
# 546140    False
# 546141    False
# Name: Nuance Liste, Length: 546142, dtype: bool

# %%
df.merge(load_and_clean_nuances(), how='left', left_on='Nuance Liste', right_on='Nuance')
# Out:
#        Code du département    Libellé du département Code commune  \
# 0                        1                       Ain            4
# 1                        1                       Ain            4
# 2                        1                       Ain            4
# 3                        1                       Ain            4
# 4                        1                       Ain            4
# ...                    ...                       ...          ...
# 546137                  ZS  Saint-Pierre-et-Miquelon          502
# 546138                  ZS  Saint-Pierre-et-Miquelon          502
# 546139                  ZS  Saint-Pierre-et-Miquelon          502
# 546140                  ZS  Saint-Pierre-et-Miquelon          502
# 546141                  ZS  Saint-Pierre-et-Miquelon          502
#
#           Libellé commune  N° Panneau Liste      Libellé abrégé liste  \
# 0       Ambérieu-en-Bugey                 1        UNIS POUR AMBERIEU
# ...
