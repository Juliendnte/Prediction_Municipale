# %%
import os
import sys

# %%
sys.path.append(os.path.abspath('../..'))

# %%
from src.preprocessing import load_and_clean_ville_stats

# %%
df = load_and_clean_ville_stats()
df.head()
# Out:
#     id_election id_brut_miom code_departement libelle_departement  \
# 0  2026_muni_t2   01160_0001               01                 Ain
# 1  2026_muni_t2   01160_0002               01                 Ain
# 2  2026_muni_t2   01160_0003               01                 Ain
# 3  2026_muni_t2   01160_0004               01                 Ain
# 4  2026_muni_t2   01194_0001               01                 Ain
#
#    code_canton libelle_canton code_commune   libelle_commune  \
# 0          NaN            NaN        01160   Ferney-Voltaire
# 1          NaN            NaN        01160   Ferney-Voltaire
# 2          NaN            NaN        01160   Ferney-Voltaire
# 3          NaN            NaN        01160   Ferney-Voltaire
# 4          NaN            NaN        01194  Jassans-Riottier
#
#    code_circonscription libelle_circonscription  ... nuls  exprimes  \
# 0                   NaN                     NaN  ...    9       380
# ...

# %%
df.shape
# Out:
# (3162440, 25)

# %%
df['id_election'].value_counts()
# Out:
# id_election
# 2024_euro_t1    70104
# 2024_legi_t1    70102
# 2026_muni_t1    70003
# 2022_pres_t2    69682
# 2022_pres_t1    69682
# 2022_legi_t1    69682
# 2022_legi_t2    69355
# 2019_euro_t1    69297
# 2017_legi_t1    69242
# 2017_pres_t2    69242
# 2017_pres_t1    69242
# 2020_muni_t1    68941
# 2017_legi_t2    68767
# 2021_regi_t1    68611
# 2021_regi_t2    68611
# 2014_euro_t1    68246
# 2014_muni_t1    68169
# 2012_legi_t1    67932
# 2012_pres_t1    67932
# 2012_pres_t2    67932
# 2015_regi_t1    67776
# 2015_regi_t2    67776
# 2009_euro_t1    66583
# 2010_regi_t1    66222
# 2021_dpmt_t1    66016
# 2010_regi_t2    65842
# 2015_dpmt_t1    65781
# 2007_legi_t1    65618
# 2007_pres_t1    65617
# 2007_pres_t2    65617
# 2004_euro_t1    64761
# 2002_pres_t2    64141
# 2002_pres_t1    64141
# 1999_euro_t1    63737
# 2002_legi_t1    63394
# 2012_legi_t2    62633
# 2004_regi_t1    62573
# 2021_dpmt_t2    62063
# 2004_regi_t2    61966
# 2024_legi_t2    61615
# 2015_dpmt_t2    60975
# ...

# %%
df = df[df['id_election'].isin(['2020_muni_t1', '2014_muni_t1', '2008_muni_t1'])]

# %%
df
# Out:
#           id_election id_brut_miom code_departement       libelle_departement  \
# 859265   2008_muni_t1   97101_0001               ZA                Guadeloupe
# 859266   2008_muni_t1   97101_0002               ZA                Guadeloupe
# 859267   2008_muni_t1   97101_0003               ZA                Guadeloupe
# 859268   2008_muni_t1   97101_0004               ZA                Guadeloupe
# 859269   2008_muni_t1   97101_0005               ZA                Guadeloupe
# ...               ...          ...              ...                       ...
# 3139955  2014_muni_t1   98758_0003               ZP       Polynésie française
# 3139956  2014_muni_t1   97501_0001               ZS  Saint-Pierre-et-Miquelon
# 3139957  2014_muni_t1   97502_0001               ZS  Saint-Pierre-et-Miquelon
# 3139958  2014_muni_t1   97502_0002               ZS  Saint-Pierre-et-Miquelon
# 3139959  2014_muni_t1   97502_0003               ZS  Saint-Pierre-et-Miquelon
#
# ...
