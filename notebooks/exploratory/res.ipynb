# %%
import os
import sys

# %%
sys.path.append(os.path.abspath('../..'))

# %%
from src.preprocessing import load_and_clean_2001_res, load_and_clean_2008_res, load_and_clean_2014_res, load_and_clean_2020_res_tour1, load_and_clean_2020_res_tour2

# %%
df_2001 = load_and_clean_2001_res()
df_2008 = load_and_clean_2008_res()
df_2014 = load_and_clean_2014_res()
df_2020_tour1 = load_and_clean_2020_res_tour1()
df_2020_tour2 = load_and_clean_2020_res_tour2()

# %%
df_2001
# Out:
#       Code du département Libellé du département Code de la commune  \
# 0                       1                    AIN                  4
# 1                       1                    AIN                 14
# 2                       1                    AIN                 33
# 3                       1                    AIN                 34
# 4                       1                    AIN                 43
# ...                   ...                    ...                ...
# 21528                  93      SEINE SAINT-DENIS                 51
# 22154                  25                  DOUBS                 56
# 22374                  33                GIRONDE                 63
# 23685                  75                  PARIS            056SR10
# 23688                  75                  PARIS            056SR13
#
#           Libellé de la commune  Population  Inscrits  Abstentions  % Abs/Ins  \
# ...

# %%
df_2008
# Out:
#                 Date export Code du département Libellé du département  \
# 0       23/05/2008 13:26:36                  ZA             GUADELOUPE
# 1       23/05/2008 13:26:36                  ZA             GUADELOUPE
# 2       23/05/2008 13:26:36                  ZA             GUADELOUPE
# 3       23/05/2008 13:26:36                  ZA             GUADELOUPE
# 4       23/05/2008 13:26:36                  ZA             GUADELOUPE
# ...                     ...                 ...                    ...
# 140523  23/05/2008 13:20:52                  95             VAL D'OISE
# 140524  23/05/2008 13:20:52                  95             VAL D'OISE
# 140525  23/05/2008 13:20:52                  95             VAL D'OISE
# 140526  23/05/2008 13:20:52                  95             VAL D'OISE
# 140527  23/05/2008 13:20:52                  95             VAL D'OISE
#
#        Code de la commune Libellé de la commune Code du bureau de vote  \
# ...

# %%
df_2014
# Out:
#         N° tour Code département  Code commune        Nom de la commune  \
# 0             1               01             1  L'Abergement-Clémenciat
# 1             1               01             1  L'Abergement-Clémenciat
# 2             1               01             1  L'Abergement-Clémenciat
# 3             1               01             1  L'Abergement-Clémenciat
# 4             1               01             1  L'Abergement-Clémenciat
# ...         ...              ...           ...                      ...
# 692024        2               ZP            58                   Uturoa
# 692025        2               ZP            58                   Uturoa
# 692026        2               ZP            58                   Uturoa
# 692027        2               ZP            58                   Uturoa
# 692028        2               ZP            58                   Uturoa
#
#        N° de bureau de vote   Inscrits   Votants   Exprimés  \
# ...

# %%
df_2020_tour1
# Out:
#        Code du département    Libellé du département  Code de la commune  \
# 0                        1                       Ain                   1
# 1                        1                       Ain                   1
# 2                        1                       Ain                   1
# 3                        1                       Ain                   1
# 4                        1                       Ain                   1
# ...                    ...                       ...                 ...
# 545347                  ZS  Saint-Pierre-et-Miquelon                 502
# 545348                  ZS  Saint-Pierre-et-Miquelon                 502
# 545349                  ZS  Saint-Pierre-et-Miquelon                 502
# 545350                  ZS  Saint-Pierre-et-Miquelon                 502
# 545351                  ZS  Saint-Pierre-et-Miquelon                 502
#
#           Libellé de la commune Code du bureau de vote  Inscrits  Abstentions  \
# ...

# %%
df_2020_tour2
# Out:
#       Code du département Libellé du département  Code de la commune  \
# 0                      01                    Ain                  12
# 1                      01                    Ain                  12
# 2                      01                    Ain                  12
# 3                      01                    Ain                  12
# 4                      01                    Ain                  12
# ...                   ...                    ...                 ...
# 85617                  ZP    Polynésie française                 758
# 85618                  ZP    Polynésie française                 758
# 85619                  ZP    Polynésie française                 758
# 85620                  ZP    Polynésie française                 758
# 85621                  ZP    Polynésie française                 758
#
#       Libellé de la commune Code du bureau de vote  Inscrits  Abstentions  \
# ...

# %%
print("df 2001 ", df_2001.columns)
print("df 2008 ", df_2008.columns)
print("df 2014 ", df_2014.columns)
print("df 2020 tour 1", df_2020_tour1.columns)
print("df 2020 tour 2", df_2020_tour2.columns)
# Out:
# df 2001  Index(['Code du département', 'Libellé du département', 'Code de la commune',
#        'Libellé de la commune', 'Population', 'Inscrits', 'Abstentions',
#        '% Abs/Ins', 'Votants', '% Vot/Ins', 'Blancs et nuls', '% BlNuls/Ins',
#        '% BlNuls/Vot', 'Exprimés', '% Exp/Ins', '% Exp/Vot', 'Nuance Liste',
#        'Libellé Abrégé Liste', 'Voix', '% Voix/Ins', '% Voix/Exp',
#        'rang_liste'],
#       dtype='object')
# df 2008  Index(['Date export', 'Code du département', 'Libellé du département',
#        'Code de la commune', 'Libellé de la commune', 'Code du bureau de vote',
#        'Inscrits', 'Abstentions', '% Abs/Ins', 'Votants', '% Vot/Ins',
#        'Blancs et nuls', '% BlNuls/Ins', '% BlNuls/Vot', 'Exprimés',
#        '% Exp/Ins', '% Exp/Vot', 'Code Nuance', 'Sexe', 'Nom', 'Prénom',
#        'Liste', 'Sièges', 'Voix', '% Voix/Ins', '% Voix/Exp'],
#       dtype='object')
# df 2014  Index(['N° tour', 'Code département', 'Code commune', 'Nom de la commune',
# ...

# %% [markdown]
# colonne a garder
# geo
# exprimé (population)
# votant
# abstention (expr - votant)
# % peuvent être recalculé pas important
# nuance
#
# A prendre en compte
# la notion de tour en 2001 2008 le site dit qu'il y a le tour 1 et 2 mais jsp comment les distinguer s'il y a une somme des deux tours ou si y a que le dernier tour
# en 2020 la nuance la plus utilisé est NC donc faut essayer de comprendre si c'est normal ou s'il faut rajouter des données
# faire attention car pas toutes les années sont distinguées par bureau de vote lorsqu'il y a le bureau de vote il y a la personne voir s'il faut perdre la données ou si on peut la rajouter
