# %%
import os
import sys

# %%
sys.path.append(os.path.abspath('../..'))

# %%
from src.preprocessing import load_and_clean_nuances

# %%
df = load_and_clean_nuances()
df
# Out:
#    Nuance                     Libellé
# 0     EXG              Extrême gauche
# 1     COM                  Communiste
# 2      PG             Parti de Gauche
# 3     SOC                  Socialiste
# 4     RDG           Radical de Gauche
# ..    ...                         ...
# 81   LMMD        Liste Majorité-MoDem
# 82   LCEN     Liste d'union du centre
# 83   LDLR  Liste Debout la République
# 84    DLR        Debout la République
# 85    LMP     Majorité présidentielle
#
# [86 rows x 2 columns]
