# %%
import os
import sys

# %% [markdown]
# Peu être utile

# %%
sys.path.append(os.path.abspath('../..'))

# %%
from src.preprocessing import load_and_clean_candidats_stats

# %%
df = load_and_clean_candidats_stats()
df.head()
# Out:
#   Code du département Libellé du département  \
# 0                  01                    Ain
# 1                  01                    Ain
# 2                  01                    Ain
# 3                  01                    Ain
# 4                  01                    Ain
#
#    Code de la collectivité à statut particulier  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Libellé de la collectivité à statut particulier Code de la commune  \
# 0                                             NaN              01001
# 1                                             NaN              01002
# 2                                             NaN              01004
# 3                                             NaN              01005
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34874 entries, 0 to 34873
# Data columns (total 14 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Code du département                              34736 non-null  object
#  1   Libellé du département                           34736 non-null  object
#  2   Code de la collectivité à statut particulier     498 non-null    float64
#  3   Libellé de la collectivité à statut particulier  498 non-null    object
#  4   Code de la commune                               34874 non-null  object
#  5   Libellé de la commune                            34874 non-null  object
#  6   Nom de l'élu                                     34874 non-null  object
#  7   Prénom de l'élu                                  34874 non-null  object
#  8   Code sexe                                        34874 non-null  object
# ...

# %%
df['Nom Prenom'] = (
    df["Nom de l'élu"].astype(str) + " " + df["Prénom de l'élu"].astype(str)
)

# %%
df['Nom Prenom'].nunique()
# Out:
# 34194

# %%
df.shape
# Out:
# (34874, 15)

# %%
df
# Out:
#       Code du département Libellé du département  \
# 0                      01                    Ain
# 1                      01                    Ain
# 2                      01                    Ain
# 3                      01                    Ain
# 4                      01                    Ain
# ...                   ...                    ...
# 34869                 NaN                    NaN
# 34870                 NaN                    NaN
# 34871                 NaN                    NaN
# 34872                 NaN                    NaN
# 34873                 NaN                    NaN
#
#        Code de la collectivité à statut particulier  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# ...
