# %%
import os
import sys

import pandas as pd

# %%
sys.path.append(os.path.abspath('../..'))

# %%
from src.preprocessing import load_and_clean_insee_2007_famille

# %%
df_famille_2007_arm = load_and_clean_insee_2007_famille(sheet="ARM")
display(df_famille_2007_arm.head(5))
# Out:
#    CODGEO                    CS2_24                               NBENFFR  \
# 0   13201  Agriculteurs exploitants       Aucun enfant de moins de 25 ans
# 1   13201  Agriculteurs exploitants           1 enfant de moins de 25 ans
# 2   13201  Agriculteurs exploitants          2 enfants de moins de 25 ans
# 3   13201  Agriculteurs exploitants          3 enfants de moins de 25 ans
# 4   13201  Agriculteurs exploitants  4 enfants ou plus de moins de 25 ans
#
#    Nombre
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df_famille_2007_com = load_and_clean_insee_2007_famille(sheet="COM")
display(df_famille_2007_com.head(5))
# Out:
#    CODGEO                    CS2_24                               NBENFFR  \
# 0  1001.0  Agriculteurs exploitants       Aucun enfant de moins de 25 ans
# 1  1001.0  Agriculteurs exploitants           1 enfant de moins de 25 ans
# 2  1001.0  Agriculteurs exploitants          2 enfants de moins de 25 ans
# 3  1001.0  Agriculteurs exploitants          3 enfants de moins de 25 ans
# 4  1001.0  Agriculteurs exploitants  4 enfants ou plus de moins de 25 ans
#
#    Nombre
# 0       0
# 1       4
# 2       4
# 3       0
# 4       0

# %%
from src.preprocessing import load_and_clean_insee_2007_menage

# %%
df_menage_2007_arm = load_and_clean_insee_2007_menage(sheet="ARM")
display(df_menage_2007_arm.head(5))
# Out:
#    CODGEO                    CS2_24        NPERC  Nombre
# 0   13201  Agriculteurs exploitants   1 personne       1
# 1   13201  Agriculteurs exploitants  2 personnes       0
# 2   13201  Agriculteurs exploitants  3 personnes       0
# 3   13201  Agriculteurs exploitants  4 personnes       0
# 4   13201  Agriculteurs exploitants  5 personnes       0

# %%
df_menage_2007_com = load_and_clean_insee_2007_menage(sheet="COM")
display(df_menage_2007_com.head(5))
# Out:
#    CODGEO                    CS2_24        NPERC  Nombre
# 0  1001.0  Agriculteurs exploitants   1 personne       0
# 1  1001.0  Agriculteurs exploitants  2 personnes       0
# 2  1001.0  Agriculteurs exploitants  3 personnes       4
# 3  1001.0  Agriculteurs exploitants  4 personnes       4
# 4  1001.0  Agriculteurs exploitants  5 personnes       0

# %%
from src.preprocessing import load_and_clean_insee_2007_diplome

df_diplome_2007_arm = load_and_clean_insee_2007_diplome(sheet="ARM")
display(df_diplome_2007_arm.head(5))
# Out:
# sexe {'1': 'Hommes', '2': 'Femmes'} ageq65 {'015': '15 à 19 ans', '020': '20 à 24 ans', '025': '25 à 29 ans', '030': '30 à 34 ans', '035': '35 à 39 ans', '040': '40 à 44 ans', '045': '45 à 49 ans', '050': '50 à 54 ans', '055': '55 à 59 ans', '060': '60 à 64 ans', '065': '65 ans ou plus'} dipl {'01': 'Pas de scolarité', '02': "Aucun diplôme mais scolarité jusqu'en école primaire ou au collège", '03': 'Aucun diplôme mais scolarité au delà du collège', '11': "Certificat d'études primaires", '12': 'BEPC, brevet élémentaire, brevet des collèges', '13': "Certificat d'aptitudes professionnelles, brevet de compagnon", '14': "Brevet d'études professionnelles", '15': 'Baccalauréat général, brevet supérieur', '16': 'Bac technologique ou professionnel, brevet professionnel ou de technicien, BEC, BEI, BEH, capacité en droit', '17': "Diplôme universitaire de 1er cycle, BTS, DUT, diplôme des professions sociales ou de santé, d'infirmier(ère)", '18': 'Diplôme universitaire de 2ème ou 3ème cycle (y c
# ...

# %%
df_diplome_2007_com = load_and_clean_insee_2007_diplome(sheet="COM")
display(df_diplome_2007_com.head(5))
# Out:
# sexe {'1': 'Hommes', '2': 'Femmes'} ageq65 {'015': '15 à 19 ans', '020': '20 à 24 ans', '025': '25 à 29 ans', '030': '30 à 34 ans', '035': '35 à 39 ans', '040': '40 à 44 ans', '045': '45 à 49 ans', '050': '50 à 54 ans', '055': '55 à 59 ans', '060': '60 à 64 ans', '065': '65 ans ou plus'} dipl {'01': 'Pas de scolarité', '02': "Aucun diplôme mais scolarité jusqu'en école primaire ou au collège", '03': 'Aucun diplôme mais scolarité au delà du collège', '11': "Certificat d'études primaires", '12': 'BEPC, brevet élémentaire, brevet des collèges', '13': "Certificat d'aptitudes professionnelles, brevet de compagnon", '14': "Brevet d'études professionnelles", '15': 'Baccalauréat général, brevet supérieur', '16': 'Bac technologique ou professionnel, brevet professionnel ou de technicien, BEC, BEI, BEH, capacité en droit', '17': "Diplôme universitaire de 1er cycle, BTS, DUT, diplôme des professions sociales ou de santé, d'infirmier(ère)", '18': 'Diplôme universitaire de 2ème ou 3ème cycle (y c
# ...

# %%
from src.preprocessing import load_and_clean_insee_2007_population

df_nationalite_2007_arm = load_and_clean_insee_2007_population(sheet="ARM")
display(df_nationalite_2007_arm.head(5))
# Out:
#    CODGEO    SEXE       AGEQ65                                        TACTR  \
# 0   13201  Hommes  15 à 19 ans                       Actifs ayant un emploi
# 1   13201  Hommes  15 à 19 ans                                     Chômeurs
# 2   13201  Hommes  15 à 19 ans                    Retraités ou préretraités
# 3   13201  Hommes  15 à 19 ans  Elèves, étudiants, stagiaires non rémunérés
# 4   13201  Hommes  15 à 19 ans                    Femmes ou hommes au foyer
#
#    Nombre
# 0     130
# 1      50
# 2       0
# 3    1152
# 4       3

# %%
df_nationalite_2007_com = load_and_clean_insee_2007_population(sheet="COM")
display(df_nationalite_2007_com.head(5))
# Out:
#    CODGEO    SEXE       AGEQ65                                        TACTR  \
# 0  1001.0  Hommes  15 à 19 ans                       Actifs ayant un emploi
# 1  1001.0  Hommes  15 à 19 ans                                     Chômeurs
# 2  1001.0  Hommes  15 à 19 ans                    Retraités ou préretraités
# 3  1001.0  Hommes  15 à 19 ans  Elèves, étudiants, stagiaires non rémunérés
# 4  1001.0  Hommes  15 à 19 ans                    Femmes ou hommes au foyer
#
#    Nombre
# 0      10
# 1       1
# 2       0
# 3      17
# 4       0

# %%
from src.preprocessing import load_and_clean_insee_2007_population2

df_nationalite_2007_arm = load_and_clean_insee_2007_population(sheet="ARM")
display(df_nationalite_2007_arm.head(5))
# Out:
#    CODGEO    SEXE       AGEQ65                                        TACTR  \
# 0   13201  Hommes  15 à 19 ans                       Actifs ayant un emploi
# 1   13201  Hommes  15 à 19 ans                                     Chômeurs
# 2   13201  Hommes  15 à 19 ans                    Retraités ou préretraités
# 3   13201  Hommes  15 à 19 ans  Elèves, étudiants, stagiaires non rémunérés
# 4   13201  Hommes  15 à 19 ans                    Femmes ou hommes au foyer
#
#    Nombre
# 0     130
# 1      50
# 2       0
# 3    1152
# 4       3

# %%
df_population_2007_com = load_and_clean_insee_2007_population(sheet="COM")
display(df_population_2007_com.head(5))
# Out:
#    CODGEO    SEXE       AGEQ65                                        TACTR  \
# 0  1001.0  Hommes  15 à 19 ans                       Actifs ayant un emploi
# 1  1001.0  Hommes  15 à 19 ans                                     Chômeurs
# 2  1001.0  Hommes  15 à 19 ans                    Retraités ou préretraités
# 3  1001.0  Hommes  15 à 19 ans  Elèves, étudiants, stagiaires non rémunérés
# 4  1001.0  Hommes  15 à 19 ans                    Femmes ou hommes au foyer
#
#    Nombre
# 0      10
# 1       1
# 2       0
# 3      17
# 4       0

# %%
from src.preprocessing import load_and_clean_insee_2007_immigration

df_immigration_2007_arm = load_and_clean_insee_2007_immigration(sheet="ARM")
display(df_immigration_2007_arm.head(5))
# Out:
#    CODGEO    SEXE             AGE4                      TACTR          IMMI  \
# 0   13201  Hommes  Moins de 15 ans     Actifs ayant un emploi      Immigrés
# 1   13201  Hommes  Moins de 15 ans     Actifs ayant un emploi  Non immigrés
# 2   13201  Hommes  Moins de 15 ans                   Chômeurs      Immigrés
# 3   13201  Hommes  Moins de 15 ans                   Chômeurs  Non immigrés
# 4   13201  Hommes  Moins de 15 ans  Retraités ou préretraités      Immigrés
#
#    Nombre
# 0       0
# 1       2
# 2       0
# 3       0
# 4       0

# %%
from src.preprocessing import load_and_clean_insee_2007_nationalite

df_nationalite_2007_arm = load_and_clean_insee_2007_nationalite(sheet="ARM")
display(df_nationalite_2007_arm.head(5))
# Out:
#    CODGEO    SEXE      INATC             AGE4  Nombre
# 0   13201  Hommes   Français  Moins de 15 ans    3023
# 1   13201  Hommes   Français      15 à 24 ans    2724
# 2   13201  Hommes   Français      25 à 54 ans    6679
# 3   13201  Hommes   Français   55 ans ou plus    3022
# 4   13201  Hommes  Etrangers  Moins de 15 ans     728

# %%
from src.preprocessing import load_and_clean_insee_2007_nationalite2

df_nationalite2_2007_arm = load_and_clean_insee_2007_nationalite2(sheet="ARM")
display(df_nationalite2_2007_arm.head(5))
# Out:
#    CODGEO    SEXE     INATC  \
# 0   13201  Hommes  Français
# 1   13201  Hommes  Français
# 2   13201  Hommes  Français
# 3   13201  Hommes  Français
# 4   13201  Hommes  Français
#
#                                                CS1_8  Nombre
# 0                           Agriculteurs exploitants       1
# 1            Artisans, commerçants, chefs entreprise     536
# 2  Cadres et professions intellectuelles supérieures    1866
# 3                         Professions intermédiaires    1773
# 4                                           Employés    1531

# %%
from src.preprocessing import load_and_clean_insee_2007_nationalite2

df_nationalite2_2007_arm = load_and_clean_insee_2007_nationalite2(sheet="ARM")
display(df_nationalite2_2007_arm.head(5))
# Out:
#    CODGEO    SEXE     INATC  \
# 0   13201  Hommes  Français
# 1   13201  Hommes  Français
# 2   13201  Hommes  Français
# 3   13201  Hommes  Français
# 4   13201  Hommes  Français
#
#                                                CS1_8  Nombre
# 0                           Agriculteurs exploitants       1
# 1            Artisans, commerçants, chefs entreprise     536
# 2  Cadres et professions intellectuelles supérieures    1866
# 3                         Professions intermédiaires    1773
# 4                                           Employés    1531

# %%
from src.preprocessing import load_and_clean_insee_2007_logement

df_logement_2007_arm = load_and_clean_insee_2007_logement(sheet="ARM")
display(df_logement_2007_arm.head(5))
# Out:
#    CODGEO    TYPLR                     CS1_8  \
# 0   13201  Maisons  Agriculteurs exploitants
# 1   13201  Maisons  Agriculteurs exploitants
# 2   13201  Maisons  Agriculteurs exploitants
# 3   13201  Maisons  Agriculteurs exploitants
# 4   13201  Maisons  Agriculteurs exploitants
#
#                                                STOCD  Nombre
# 0                                       Propriétaire       0
# 1  Locataire ou sous-locataire d'un logement loué...       0
# 2  Locataire ou sous-locataire d'un logement loué...       0
# 3  Locataire ou sous-locataire d'un logement loué...       0
# 4                                  Logé gratuitement       0

# %%
df_logement_2007_com = load_and_clean_insee_2007_logement(sheet="COM")
display(df_logement_2007_com.head(5))
# Out:
#    CODGEO    TYPLR                     CS1_8  \
# 0  1001.0  Maisons  Agriculteurs exploitants
# 1  1001.0  Maisons  Agriculteurs exploitants
# 2  1001.0  Maisons  Agriculteurs exploitants
# 3  1001.0  Maisons  Agriculteurs exploitants
# 4  1001.0  Maisons  Agriculteurs exploitants
#
#                                                STOCD  Nombre
# 0                                       Propriétaire       4
# 1  Locataire ou sous-locataire d'un logement loué...       4
# 2  Locataire ou sous-locataire d'un logement loué...       0
# 3  Locataire ou sous-locataire d'un logement loué...       0
# 4                                  Logé gratuitement       0

# %%
from src.preprocessing import load_and_clean_insee_2007_emploi

df_emploi_2007_1arm = load_and_clean_insee_2007_emploi(sheet="1_ARM")
display(df_emploi_2007_1arm.head(5))
# Out:
#    CODGEO    SEXE                                CS3_31  \
# 0   13201  Hommes  Agriculteurs sur petite exploitation
# 1   13201  Hommes  Agriculteurs sur petite exploitation
# 2   13201  Hommes  Agriculteurs sur petite exploitation
# 3   13201  Hommes  Agriculteurs sur petite exploitation
# 4   13201  Hommes  Agriculteurs sur petite exploitation
#
#                                                  NA5  Nombre
# 0                 Agriculture, sylviculture et pêche       0
# 1  Industrie manufacturière, industries extractiv...       0
# 2                                       Construction       0
# 3            Commerce, transports et services divers       0
# 4  Administration publique, enseignement, santé h...       0

# %%
df_emploi_2007_2arm = load_and_clean_insee_2007_emploi(sheet="2_ARM")
display(df_emploi_2007_2arm.head(10))
# Out:
#    CODGEO  SEXE                                CS3_31  \
# 0   13201  None               Policiers et militaires
# 1   13201  None               Policiers et militaires
# 2   13201  None               Policiers et militaires
# 3   13201  None               Policiers et militaires
# 4   13201  None               Policiers et militaires
# 5   13201  None  Employés administratifs d'entreprise
# 6   13201  None  Employés administratifs d'entreprise
# 7   13201  None  Employés administratifs d'entreprise
# 8   13201  None  Employés administratifs d'entreprise
# 9   13201  None  Employés administratifs d'entreprise
#
#                                                  NA5  Nombre
# 0                 Agriculture, sylviculture et pêche       0
# 1  Industrie manufacturière, industries extractiv...       0
# 2                                       Construction       0
# 3            Commerce, transports et services divers       9
# 4  Administration publique, enseignement, santé h...      68
# ...

# %%
df_emploi_2007_2com = load_and_clean_insee_2007_emploi(sheet="1_COM")
display(df_emploi_2007_2com.head(5))
# Out:
#    CODGEO    SEXE                                CS3_31  \
# 0  1001.0  Hommes  Agriculteurs sur petite exploitation
# 1  1001.0  Hommes  Agriculteurs sur petite exploitation
# 2  1001.0  Hommes  Agriculteurs sur petite exploitation
# 3  1001.0  Hommes  Agriculteurs sur petite exploitation
# 4  1001.0  Hommes  Agriculteurs sur petite exploitation
#
#                                                  NA5  Nombre
# 0                 Agriculture, sylviculture et pêche       4
# 1  Industrie manufacturière, industries extractiv...       0
# 2                                       Construction       0
# 3            Commerce, transports et services divers       0
# 4  Administration publique, enseignement, santé h...       0

# %%
df_emploi_2007_2com = load_and_clean_insee_2007_emploi(sheet="2_COM")
display(df_emploi_2007_2com.head(5))
# Out:
#    CODGEO  SEXE                   CS3_31  \
# 0  1001.0  None  Policiers et militaires
# 1  1001.0  None  Policiers et militaires
# 2  1001.0  None  Policiers et militaires
# 3  1001.0  None  Policiers et militaires
# 4  1001.0  None  Policiers et militaires
#
#                                                  NA5  Nombre
# 0                 Agriculture, sylviculture et pêche       0
# 1  Industrie manufacturière, industries extractiv...       0
# 2                                       Construction       0
# 3            Commerce, transports et services divers       0
# 4  Administration publique, enseignement, santé h...       0

# %%
from src.preprocessing import (
    load_and_clean_insee_2013_famille,
    load_and_clean_insee_2013_menage,
    load_and_clean_insee_2013_diplome,
    load_and_clean_insee_2013_population,
    load_and_clean_insee_2013_population2,
    load_and_clean_insee_2013_nationalite,
    load_and_clean_insee_2013_nationalite2,
    load_and_clean_insee_2013_logement,
    load_and_clean_insee_2013_emploi,
    load_and_clean_insee_2013_immigration,
)

df_famille_2013_com      = load_and_clean_insee_2013_famille(sheet="COM")
df_menage_2013_com       = load_and_clean_insee_2013_menage(sheet="COM")
df_diplome_2013_com      = load_and_clean_insee_2013_diplome(sheet="COM")
df_population_2013_com   = load_and_clean_insee_2013_population(sheet="COM")
df_population2_2013_com  = load_and_clean_insee_2013_population2(sheet="COM")
df_nationalite_2013_com  = load_and_clean_insee_2013_nationalite(sheet="COM")
df_nationalite2_2013_com = load_and_clean_insee_2013_nationalite2(sheet="COM")
df_logement_2013_com     = load_and_clean_insee_2013_logement(sheet="COM")
df_emploi_2013_com       = load_and_clean_insee_2013_emploi(sheet="COM")
df_immigration_2013_com  = load_and_clean_insee_2013_immigration(sheet="COM")

display(df_diplome_2013_com.head(5))
# Out:
#   CODGEO                   LIBGEO       AGEQ65  \
# 0  01001  L'Abergement-Clémenciat  15 à 19 ans
# 1  01002    L'Abergement-de-Varey  15 à 19 ans
# 2  01004        Ambérieu-en-Bugey  15 à 19 ans
# 3  01005      Ambérieux-en-Dombes  15 à 19 ans
# 4  01006                  Ambléon  15 à 19 ans
#
#                                                 DIPL    SEXE  Nombre
# 0  Aucun diplôme ou au plus BEPC, brevet des coll...  Hommes       0
# 1  Aucun diplôme ou au plus BEPC, brevet des coll...  Hommes       0
# 2  Aucun diplôme ou au plus BEPC, brevet des coll...  Hommes      51
# 3  Aucun diplôme ou au plus BEPC, brevet des coll...  Hommes       3
# 4  Aucun diplôme ou au plus BEPC, brevet des coll...  Hommes       1

# %%
from src.preprocessing import (
    load_and_clean_insee_2013_famille,
    load_and_clean_insee_2013_menage,
    load_and_clean_insee_2013_diplome,
    load_and_clean_insee_2013_population,
    load_and_clean_insee_2013_population2,
    load_and_clean_insee_2013_nationalite,
    load_and_clean_insee_2013_nationalite2,
    load_and_clean_insee_2013_logement,
    load_and_clean_insee_2013_emploi,
    load_and_clean_insee_2013_immigration,
)

df_famille_2013_arm      = load_and_clean_insee_2013_famille(sheet="ARM")
df_menage_2013_arm       = load_and_clean_insee_2013_menage(sheet="ARM")
df_diplome_2013_arm      = load_and_clean_insee_2013_diplome(sheet="ARM")
df_population_2013_arm   = load_and_clean_insee_2013_population(sheet="ARM")
df_population2_2013_arm  = load_and_clean_insee_2013_population2(sheet="ARM")
df_nationalite_2013_arm  = load_and_clean_insee_2013_nationalite(sheet="ARM")
df_nationalite2_2013_arm = load_and_clean_insee_2013_nationalite2(sheet="ARM")
df_logement_2013_arm     = load_and_clean_insee_2013_logement(sheet="ARM")
df_emploi_2013_arm       = load_and_clean_insee_2013_emploi(sheet="ARM")
df_immigration_2013_arm  = load_and_clean_insee_2013_immigration(sheet="ARM")

display(df_diplome_2013_arm.head(5))
display(df_famille_2013_arm.head(5))
display(df_menage_2013_arm.head(5))
display(df_immigration_2013_arm.head(5))
display(df_emploi_2013_arm.head(5))
display(df_logement_2013_arm.head(5))
display(df_nationalite_2013_arm.head(5))
display(df_nationalite2_2013_arm.head(5))
display(df_population_2013_arm.head(5))
display(df_population2_2013_arm.head(5))
# Out:
#   CODGEO                        LIBGEO       AGEQ65  \
# 0  13201  Marseille 1er Arrondissement  15 à 19 ans
# 1  13202   Marseille 2e Arrondissement  15 à 19 ans
# 2  13203   Marseille 3e Arrondissement  15 à 19 ans
# 3  13204   Marseille 4e Arrondissement  15 à 19 ans
# 4  13205   Marseille 5e Arrondissement  15 à 19 ans
#
#                                                 DIPL    SEXE  Nombre
# 0  Aucun diplôme ou au plus BEPC, brevet des coll...  Hommes      77
# 1  Aucun diplôme ou au plus BEPC, brevet des coll...  Hommes      72
# 2  Aucun diplôme ou au plus BEPC, brevet des coll...  Hommes     160
# 3  Aucun diplôme ou au plus BEPC, brevet des coll...  Hommes      75
# 4  Aucun diplôme ou au plus BEPC, brevet des coll...  Hommes      88
#   CODGEO                        LIBGEO                    CS2_24  \
# 0  13201  Marseille 1er Arrondissement  Agriculteurs exploitants
# 1  13202   Marseille 2e Arrondissement  Agriculteurs exploitants
# ...

# %%
from src.preprocessing import (
    load_and_clean_insee_2019_famille,
    load_and_clean_insee_2019_menage,
    load_and_clean_insee_2019_diplome,
    load_and_clean_insee_2019_population,
    load_and_clean_insee_2019_population2,
    load_and_clean_insee_2019_nationalite,
    load_and_clean_insee_2019_nationalite2,
    load_and_clean_insee_2019_logement,
    load_and_clean_insee_2019_emploi,
    load_and_clean_insee_2019_immigration,
)

df_famille_2019_com      = load_and_clean_insee_2019_famille(sheet="COM")
df_menage_2019_com       = load_and_clean_insee_2019_menage(sheet="COM")
df_diplome_2019_com      = load_and_clean_insee_2019_diplome(sheet="COM")
df_population_2019_com   = load_and_clean_insee_2019_population(sheet="COM")
df_population2_2019_com  = load_and_clean_insee_2019_population2(sheet="COM")
df_nationalite_2019_com  = load_and_clean_insee_2019_nationalite(sheet="COM")
df_nationalite2_2019_com = load_and_clean_insee_2019_nationalite2(sheet="COM")
df_logement_2019_com     = load_and_clean_insee_2019_logement(sheet="COM")
df_emploi_2019_com       = load_and_clean_insee_2019_emploi(sheet="COM")
# df_immigration_2019_com = load_and_clean_insee_2019_immigration(sheet="COM")
#   ^ pas de feuille COM pour ce fichier en 2019 (seulement C.O.M. = outre-mer)

display(df_diplome_2019_com.head(5))
# Out:
#   CODGEO                   LIBGEO       AGEQ65  \
# 0  01001  L'Abergement-Clémenciat  15 à 19 ans
# 1  01002    L'Abergement-de-Varey  15 à 19 ans
# 2  01004        Ambérieu-en-Bugey  15 à 19 ans
# 3  01005      Ambérieux-en-Dombes  15 à 19 ans
# 4  01006                  Ambléon  15 à 19 ans
#
#                                              DIPL    SEXE  Nombre
# 0  Aucun diplôme ou certificat d'études primaires  Hommes       1
# 1  Aucun diplôme ou certificat d'études primaires  Hommes       0
# 2  Aucun diplôme ou certificat d'études primaires  Hommes      32
# 3  Aucun diplôme ou certificat d'études primaires  Hommes       1
# 4  Aucun diplôme ou certificat d'études primaires  Hommes       0
