# %%
from src.preprocessing import load_and_clean_insee_2019_diplomes

# %%
df_diplome_2019 = load_and_clean_insee_2019_diplomes()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_diplome_2019 = load_and_clean_insee_2019_diplomes()
#
# File ~/projects/Prediction_Municipale/src/preprocessing.py:350, in load_and_clean_insee_2019_diplomes()
#     349 def load_and_clean_insee_2019_diplomes():
# --> 350     return depivot_insee_com(RAW_DATA_FILES["INSEE_2019_Dip"])
#
# File ~/projects/Prediction_Municipale/src/preprocessing.py:308, in depivot_insee_com(filepath, value_name)
#     305 id_cols = ["CODGEO", "LIBGEO"]
#     306 value_cols = [col for col in df.columns if col not in id_cols]
# --> 308 df_long = df.melt(
#     309     id_vars=id_cols,
#     310     value_vars=value_cols,
#     311     var_name="variable_insee",
#     312     value_name=value_name,
#     313 )
#     315 variable_pattern = re.compile(
# ...

# %%
df_diplome_2019
